# %% [markdown]
# ## Imports:

# %%
# ================================================
# ÉPICA 1 - Procesamiento de imágenes
# HU1 + HU2
# ================================================

# 1. Librerías necesarias
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import rasterio

from paths import get_estanzuela_path, get_ortomosaico_path, list_imagenes

# Configuración para gráficos
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ### Ejemplo de uso de paths.py

# %%
# Ruta a la campaña del 17 de enero
#path_17ene = get_estanzuela_path("17ene2025")
#print("Ruta campaña:", path_17ene)

# Listar imágenes de esa campaña
#imagenes = list_imagenes(path_17ene)
#print("Imágenes encontradas:", imagenes)

# Ruta al ortomosaico del 24 de enero
#path_orto = get_ortomosaico_path("24ene")
#print("Ruta ortomosaico:", path_orto)
